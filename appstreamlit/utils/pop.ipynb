# %%
import plotly
import streamlit as st
import pandas as pd
import  numpy as pn
import shap as sh
import joblib as job
import matplotlib as plt
import flask as fla

import scipy as sc

print("Plotly version :", plotly.__version__)
print("Streamlit version :", st.__version__)
print("pn version :", pn.__version__)
print("pd version :", pd.__version__)
print("job version :", job.__version__)
print("plt version :", plt.__version__)
print("shap version :", sh.__version__)
print("fla version :", fla.__version__)

print("sc version :", sc.__version__)
import evidently
print(evidently.__version__)
# Out:
# Plotly version : 5.24.1
# Streamlit version : 1.48.1
# pn version : 1.26.0
# pd version : 2.2.2
# job version : 1.3.2
# plt version : 3.9.0
# shap version : 0.46.0
# fla version : 2.2.5
# sc version : 1.11.3
# 0.4.38
